# %%
import numpy as np

# %%
# %matplotlib inline

# %%
import seaborn as sns

# %%
import scipy.stats as sp

# %% [markdown]
# ## Create data

# %%
X = np.random.normal(5,1,100)

# %%
sns.distplot(X)

# %%
s = 1000
B = 1000

estimates = []
means = []

for i in range(B):
    sample = np.random.choice(X, size=s)
    x_bar = np.mean(sample)
    means.append(x_bar)
    estimates.append(np.exp(x_bar))

# %%
sns.distplot(means)

# %%
sns.distplot(estimates)

# %%
theta_hat = np.mean(estimates)
se_hat = np.std(estimates)

# %%
(theta_hat, theta_hat-1.96*se_hat, theta_hat+1.96*se_hat)
# Out:
# (146.05365298391774, 138.21601676219981, 153.89128920563567)
